# %%
from sympy import symbols, solve
from sympy.plotting import plot
# import finder

# %%
x = symbols('x')
f = 0.6*(x**3) + 5.5*(x**2) + 10*x -5
f
# Out:
# 0.6*x**3 + 5.5*x**2 + 10*x - 5

# %%
plot(f, (x, -10, 3))

# %%
roots = list(map(lambda x: round(x, 3), solve(f)))
roots
# Out:
# [-6.322, -3.250, 0.406]
